# %%
import pandas as pd
credits = pd.read_csv(r"C:\Users\vanshveer\Downloads\movies.csv")

# %%
credits.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
import pandas as pd
credits = pd.read_csv(r"C:\Users\vanshveer\Downloads\movies.csv")
actor_name = input("Enter an Actor")
actor_movies = credits[credits['star'] == actor_name]
# Sort the filtered DataFrame by 'score' column in descending order
sorted_movies = actor_movies.sort_values(by='score', ascending=False)

# Display the top 5 rated movies of the actor
top_5_movies = sorted_movies.head(5)['name']
print("Top 5 rated movies of", actor_name)
print(top_5_movies)
# Out:
# Enter an ActorPaul Walker
# Top 5 rated movies of Paul Walker
# 4868      Running Scared
# 4985         Eight Below
# 4250    2 Fast 2 Furious
# 4693       Into the Blue
# 4277            Timeline
# Name: name, dtype: object

# %%
# Replace "Tom Hanks" with the actor's name you're interested in
actor_name = "Tom Hanks"

# Function to check if the actor is in the cast of a movie
def is_actor_in_cast(movie_cast, actor_name):
    for actor in movie_cast:
        if actor_name.lower() in actor.lower():
            return True
    return False

# Filter the DataFrame to include only movies featuring the specified actor
actor_movies = movies[movies['cast'].apply(lambda x: is_actor_in_cast(x, actor_name))]

# Sort the filtered DataFrame by 'score' column in descending order if 'score' column is present
if 'score' in movies.columns:
    sorted_movies = actor_movies.sort_values(by='score', ascending=False)
else:
    sorted_movies = actor_movies  # If 'score' column is not present, no sorting is performed

# Extract only the 'title' column of the top 5 rated movies
top_5_movies_titles = sorted_movies.head(5)['title']

# Display the top 5 rated movies' titles of the actor
print("Top 5 rated movies of", actor_name)
print(top_5_movies_titles)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 12
#       9     return False
#      11 # Filter the DataFrame to include only movies featuring the specified actor
# ---> 12 actor_movies = movies[movies['cast'].apply(lambda x: is_actor_in_cast(x, actor_name))]
#      14 # Sort the filtered DataFrame by 'score' column in descending order if 'score' column is present
#      15 if 'score' in movies.columns:
#
# NameError: name 'movies' is not defined
